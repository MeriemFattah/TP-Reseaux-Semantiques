# %% [markdown]
# ##TP : Réseaux sémantiques

# %% [markdown]
# Réalisé par : Meriem Fattah

# %%
import networkx as nx
import matplotlib.pyplot as plt

# %% [markdown]
# # Création du graphe

# %%
G = nx.DiGraph()

# %% [markdown]
# # Ajout des nœuds

# %%
concepts = ["chien", "animal", "viande", "nourriture", "chat", "être vivant", "respirer"]
G.add_nodes_from(concepts)

# %% [markdown]
# # Ajout des arêtes avec les relations

# %%
relations = [
    ("chien", "animal", "est un"),
    ("chien", "viande", "mange"),
    ("viande", "nourriture", "est un"),
    ("chat", "animal", "est un"),
    ("animal", "être vivant", "est un"),
    ("être vivant", "respirer", "a besoin de")
]

# %%
for start, end, relation in relations:
    G.add_edge(start, end, label=relation)

# %% [markdown]
# # Dessiner le réseau

# %%
pos = nx.spring_layout(G)
node_size = 2000
font_size = 12

# %% [markdown]
# # Visualiser et dessiner les nœuds et les arêtes

# %%
fig, ax = plt.subplots(figsize=(12, 8))
nx.draw(G, pos, with_labels=True, node_size=node_size, node_color="skyblue",
        font_size=font_size, font_weight="bold", arrows=True)
nx.draw_networkx_edge_labels(G, pos, edge_labels=nx.get_edge_attributes(G, 'label'),
                            font_color="red", font_size=font_size-2)
# Out:
# {('chien',
#   'animal'): Text(-0.16774750799293237, 0.05108749052691397, 'est un'),
#  ('chien', 'viande'): Text(0.5455029406482768, 0.19744029247030548, 'mange'),
#  ('animal',
#   'être vivant'): Text(-0.5574861968805775, -0.15612181990337493, 'est un'),
#  ('viande',
#   'nourriture'): Text(0.949966483462874, 0.38838410780159427, 'est un'),
#  ('chat',
#   'animal'): Text(-0.42824766241311985, -0.015405643991580287, 'est un'),
#  ('être vivant',
#   'respirer'): Text(-0.6172572187037441, -0.43585759117538375, 'a besoin de')}

# %% [markdown]
# # Afficher les relations associées au concept "chien"

# %%
print("Relations associées au concept 'chien' :")
for neighbor in G.neighbors("chien"):
    relation = G["chien"][neighbor]["label"]
    print(f"chien -> {neighbor} ({relation})")
# Out:
# Relations associées au concept 'chien' :
# chien -> animal (est un)
# chien -> viande (mange)

# %% [markdown]
# # Vérifier la relation entre "chien" et "animal"

# %%
if G.has_edge("chien", "animal"):
    print("\nRelation entre 'chien' et 'animal' :")
    print(f"chien -> animal ({G['chien']['animal']['label']})")
else:
    print("\nAucune relation directe entre 'chien' et 'animal'.")
# Out:
# Relation entre 'chien' et 'animal' :
# chien -> animal (est un)
